# %%
# %%html
# <script src="/files/js/d3.v3.js"></script>
# <script src="/files/js/nv.d3.js"></script>
# Out:
# <script src="/files/js/d3.v3.js"></script>
# <script src="/files/js/nv.d3.js"></script>

# %%
data = {
    "foo": "bar",
    "baz": "ban"
}

# %%
import json
print(json.dumps(data))
# Out:
# {"foo": "bar", "baz": "ban"}

# %%
# %%javascript
# var data = JSON.parse(IPython.notebook.get_cell(2).toJSON()["outputs"][0]["text"])
# console.dir(data)

# %%
# %%html
# <div id="dataviz-chart"></div>
# Out:
# <div id="dataviz-chart"></div>

# %%
# %%javascript
# var foo = {};

# %%
from pandas import options
options.display.mpl_style = 'default'
options.display.max_columns = 100
options.display.line_width = 4000
import pandas as pd

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
